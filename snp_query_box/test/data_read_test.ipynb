# %%
import os
from snp_query_box import DsnpHelperFunction
import pkg_resources
import pandas as pd

# %%
DsnpHelperFunction.get_hedis_patient_safety_measure()
# Out:
#    MEASURE_ID                                         MEASURE_NM
# 0      101803                         Controlling Blood Pressure  \
# 1      102401                        Colorectal Cancer Screening
# 2      104201  Osteoporosis Management in Women who had a Fra...
# 3      107125          Care for Older Adults - Medication Review
# 4      107126  Care for Older Adults - Functional Status Asse...
# 5      107127            Care for Older Adults - Pain Assessment
# 6      201180     Medication Adherence for Cholesterol (Statins)
# 7      201181  Medication Adherence for Hypertension (RAS ant...
# 8      201182      Medication Adherence for Diabetes Medications
# 9      201183         Statin Use in Persons with Diabetes (SUPD)
# 10     201184                MTM Program Completion Rate for CMR
# 11     201507  Statin Therapy for Patients with Cardiovascula...
# 12     600070           Medication Reconciliation Post-Discharge
# ...

# %%
DsnpHelperFunction.get_dsnp_cm_manager_map()
# Out:
#     Product Contract  PBP H Plan-PBP  Full/Partial
# 0      MAPD    H3239    2  H3239-002  Full/Partial  \
# 1      MAPD    H3239    3  H3239-003  Full/Partial
# 2      MAPD    H3239   10  H3239-010  Full/Partial
# 3      MAPD    H3239   18  H3239-018  Full/Partial
# 4      MAPD    H3239   19  H3239-019  Full/Partial
# ..      ...      ...  ...        ...           ...
# 103    MAPD    H8649   10  H8649-010  Full/Partial
# 104    MAPD    H1610    1  H1610-001          Full
# 105    MAPD    H1610    2  H1610-002          Full
# 106    MAPD    H1610    3  H1610-003       Partial
# 107    MAPD    H1692    5  H1692-005  Full/Partial
#
#             99: State Capitation MSP Levels    Plan Market State Code
# 0    QMB, QMB+, SLMB, SLMB+, FBDE, QDWI, QI        Alabama         AL  \
# 1    QMB, QMB+, SLMB, SLMB+, FBDE, QDWI, QI        Alabama         AL
# 2    QMB, QMB+, SLMB, SLMB+, FBDE, QDWI, QI        Alabama         AL
# ...

# %%
DsnpHelperFunction.get_dsnp_market_crosswalk()
# Out:
#    Contract_Number DSNP_Contract_Status
# 0            H0628           Co-Mingled
# 1            H0901           Co-Mingled
# 2            H1013           Co-Mingled
# 3            H1076           Co-Mingled
# 4            H1419           Co-Mingled
# 5            H1608           Co-Mingled
# 6            H1609           Co-Mingled
# 7            H1610            DSNP-FIDE
# 8            H1692           Co-Mingled
# 9            H2112           Co-Mingled
# 10           H2293           Co-Mingled
# 11           H2663           Co-Mingled
# 12           H2667           Co-Mingled
# 13           H2672           Co-Mingled
# 14           H3146           Co-Mingled
# 15           H3152           Co-Mingled
# 16           H3192           Co-Mingled
# 17           H3239           Co-Mingled
# 18           H3312           Co-Mingled
# 19           H3597           Co-Mingled
# 20           H3931           Co-Mingled
# 21           H3959           Co-Mingled
# ...

# %%
DsnpHelperFunction.get_dsnp_contract_pbp_state_mapping_file()
# Out:
#     Contract_Number  PBP dsnp_state
# 0             H0628  012         KY
# 1             H0628  013         OH
# 2             H0628  018         OH
# 3             H1608  062         SD
# 4             H1608  076         AR
# ..              ...  ...        ...
# 103           H7149  006         NE
# 104           H8597  001         TX
# 105           H8597  002         TX
# 106           H8597  003         TX
# 107           H8649  010         UT
#
# [108 rows x 3 columns]

# %%
DsnpHelperFunction.get_hcpcs_lookup()
# Out:
#      hcpcs_code                                  hcpcs_description
# 0         A0021  Ambulance service, outside state per mile, tra...  \
# 1         A0080  Non-emergency transportation, per mile - vehic...
# 2         A0090  Non-emergency transportation, per mile - vehic...
# 3         A0100                 Non-emergency transportation; taxi
# 4         A0110  Non-emergency transportation and bus, intra or...
# ...         ...                                                ...
# 7961      V5299                     Hearing service, miscellaneous
# 7962      V5336  Repair/modification of augmentative communicat...
# 7963      V5362                                   Speech screening
# 7964      V5363                                 Language screening
# 7965      V5364                                Dysphagia screening
#
#      file_release_date
# 0           2024-04-01
# 1           2024-04-01
# 2           2024-04-01
# 3           2024-04-01
# 4           2024-04-01
# ...

# %%
DsnpHelperFunction.get_revenue_code_lookup()
# Out:
#     revenue_code_string  revenue_code_numeric
# 0                  0022                    22  \
# 1                  0023                    23
# 2                  0024                    24
# 3                  0100                   100
# 4                  0101                   101
# ..                  ...                   ...
# 533                3103                  3103
# 534                3104                  3104
# 535                3105                  3105
# 536                3109                  3109
# 537                0952                   952
#
#                          revenue_code_description
# 0                    Skilled Nursing Facility PPS  \
# 1                                 Home Health PPS
# 2     Inpatient Rehabilitation Facility (IRF) PPS
# 3     All inclusive room and board plus ancillary
# 4                    All inclusive room and board
# ..                                            ...
# 533    Adult daycare, medical and social  - daily
# ...

# %%
DsnpHelperFunction.get_diagnosis_code_lookup()
# Out:
#       diagnosis_code  billable
# 0                A00         0  \
# 1               A000         1
# 2               A001         1
# 3               A009         1
# 4                A01         0
# ...              ...       ...
# 97291            U07         0
# 97292           U070         1
# 97293           U071         1
# 97294            U09         0
# 97295           U099         1
#
#                         diagnosis_code_short_description
# 0                                                Cholera  \
# 1      Cholera due to Vibrio cholerae 01, biovar chol...
# 2        Cholera due to Vibrio cholerae 01, biovar eltor
# 3                                   Cholera, unspecified
# 4                         Typhoid and paratyphoid fevers
# ...                                                  ...
# 97291                               Emergency use of U07
# 97292                            Vaping-related disorder
# 97293                                           COVID-19
# ...

# %%
DsnpHelperFunction.get_diagnosis_code_lookup("Cholera")
# Out:
#       diagnosis_code  billable
# 0                A00         0  \
# 1               A000         1
# 2               A001         1
# 3               A009         1
# 4                A01         0
# ...              ...       ...
# 97291            U07         0
# 97292           U070         1
# 97293           U071         1
# 97294            U09         0
# 97295           U099         1
#
#                         diagnosis_code_short_description
# 0                                                Cholera  \
# 1      Cholera due to Vibrio cholerae 01, biovar chol...
# 2        Cholera due to Vibrio cholerae 01, biovar eltor
# 3                                   Cholera, unspecified
# 4                         Typhoid and paratyphoid fevers
# ...                                                  ...
# 97291                               Emergency use of U07
# 97292                            Vaping-related disorder
# 97293                                           COVID-19
# ...

# %%
DsnpHelperFunction.get_diagnosis_code_lookup("Vibrio")
# Out:
#       diagnosis_code  billable
# 0                A00         0  \
# 1               A000         1
# 2               A001         1
# 3               A009         1
# 4                A01         0
# ...              ...       ...
# 97291            U07         0
# 97292           U070         1
# 97293           U071         1
# 97294            U09         0
# 97295           U099         1
#
#                         diagnosis_code_short_description
# 0                                                Cholera  \
# 1      Cholera due to Vibrio cholerae 01, biovar chol...
# 2        Cholera due to Vibrio cholerae 01, biovar eltor
# 3                                   Cholera, unspecified
# 4                         Typhoid and paratyphoid fevers
# ...                                                  ...
# 97291                               Emergency use of U07
# 97292                            Vaping-related disorder
# 97293                                           COVID-19
# ...
