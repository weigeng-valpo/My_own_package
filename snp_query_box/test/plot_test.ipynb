# %%
import os
import sys
import pandas as pd
from snp_query_box import hraQueries
user_id = "A845514"
os.getcwd()
current_dir = os.getcwd()
parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))
sys.path.append(f'{parent_dir}')

# %%
import dsnpStyle
dsnpStyle.aetna_dsnp_plot_style()

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
#from snp_query_box import dsnpStyle
x=np.random.randn(100)
g = sns.displot(x)
plt.show()

# %%
data = {
    'group_a': np.random.normal(loc=0, scale=1, size=100),
    'group_b': np.random.normal(loc=1, scale=1, size=100),
    'group_c': np.random.normal(loc=1, scale=1, size=100),
    'group_d': np.random.normal(loc=1, scale=1, size=100),
    'group_e': np.random.normal(loc=1, scale=1, size=100),
}

df = pd.DataFrame(data)
sns.violinplot(data=df, split =True)
# Out:
# <Axes: >

# %%
df = pd.DataFrame(data)
sns.violinplot(data=df, split =True, color = dsnpStyle.aetna_palette["dark_red"])
# Out:
# <Axes: >
